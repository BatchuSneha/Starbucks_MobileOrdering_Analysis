# %%
# print all the outputs in a cell
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
import seaborn as sns
import pandas as pd
import numpy as np

# %%
order_detail  = pd.read_csv('Customer_Order_Detail.csv', index_col=0)

# %%
menu = pd.read_csv('Menu.csv', index_col=0)

# %%
order_detail.head()
# Out:
#                order_id menu_id  item_price milk_type preparation_type  \
# order_line_id
# 101_1               101    m001        5.25       NaN              Hot
# 101_2               101    m037        5.25       NaN              Hot
# 102_1               102    m051        6.25       NaN             Cold
# 102_2               102    m065        7.00       NaN             None
# 103_1               103    m042        6.25       NaN             Cold
#
#               customization1  customization2  customization3  customization4
# order_line_id
# 101_1                    NaN             NaN             NaN             NaN
# 101_2                    NaN             NaN             NaN             NaN
# 102_1             "less ice"             NaN             NaN             NaN
# 102_2                    NaN             NaN             NaN             NaN
# 103_1                    NaN             NaN             NaN             NaN

# %%
menu.head()
# Out:
#          product_code          item_description item_type category_type  \
# menu_id
# m001            10100   dark_roast_brewed_short     drink    hot_coffee
# m002            10200    dark_roast_brewed_tall     drink    hot_coffee
# m003            10300  dark_roast_brewed_grande     drink    hot_coffee
# m004            10400   dark_roast_brewed_venti     drink    hot_coffee
# m005            10500   pike_place_brewed_short     drink    hot_coffee
#
#         subcategory_type  item_price  preparation_type  customization1  \
# menu_id
# m001       brewed_coffee        5.25  beverage_machine             NaN
# m002       brewed_coffee        5.50  beverage_machine             NaN
# m003       brewed_coffee        6.25  beverage_machine             NaN
# m004       brewed_coffee        6.50  beverage_machine             NaN
# m005       brewed_coffee        5.25  beverage_machine             NaN
#
#          customization2  customization3  customization4
# menu_id
# ...

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
items_ordered = order_detail.merge(menu, left_on='menu_id',right_on='menu_id')

# %%
items_ordered
# Out:
#     order_id menu_id  item_price_x       milk_type preparation_type_x  \
# 0        101    m001          5.25             NaN                Hot
# 1        101    m037          5.25             NaN                Hot
# 2        102    m051          6.25             NaN               Cold
# 3        102    m065          7.00             NaN               None
# 4        107    m065          7.00             NaN                Hot
# 5        108    m065          7.00             NaN                Hot
# 6        109    m065          7.00             NaN                Hot
# 7        103    m042          6.25             NaN               Cold
# 8        103    m010          5.50  2_percent_milk                Hot
# 9        103    m071          3.25             NaN               None
# 10       104    m056          5.50             NaN               Cold
# 11       105    m043          6.50             NaN               Cold
# ...

# %%
df4.groupby('Zip Code')['Churn Value'].sum().sort_values(ascending=False).nlargest(20).plot(kind='bar')

# %%
total_ordered = items_ordered.groupby('item_description')[['item_price_x']].sum()
total_ordered
# Out:
#                              item_price_x
# item_description
# bacon_egg_cheese_swich              14.00
# blueberry_muffin                     9.00
# butter_croissant                     3.25
# caffe_latte_tall                     5.50
# caramel_frap_grande                  6.25
# caramel_frap_venti                   6.50
# cold_brew_grande                     6.25
# dark_caramel_sauce                   0.50
# dark_roast_brewed_short              5.25
# impossible_bfast_swich              28.00
# mocha_frap_venti                     6.50
# peach_tranquility_tea_short          5.25
# pink_drink_venti                    13.00
# star_drink_tall                      5.50
# sugar_cookie_syrup                   0.50

# %%
items_ordered.groupby('item_description')['item_price_x'].sum().sort_values(ascending=True).plot(kind='barh')
# Out:
# <AxesSubplot:ylabel='item_description'>

# %%
items_ordered.groupby('item_description')['menu_id'].count().sort_values(ascending=True).plot(kind='barh')
# Out:
# <AxesSubplot:ylabel='item_description'>
